# %% [markdown]
# # text2sql-rag — Phase 1 placeholder
#
# Use this notebook for ad-hoc experiments once Spider is downloaded and the virtual environment is activated.
#
# Suggested flow:
# 1. `from text2sql_rag.config import load_config`
# 2. `from text2sql_rag.schema_indexer import SchemaIndexer` then `SchemaIndexer(load_config()).build_from_spider()`
# 3. `from text2sql_rag.schema_linker import SchemaLinker` and call `link(...)`
#
# Configure `SPIDER_DATA_DIR` in `.env` per README.

# %%
# Placeholder code cell
print("Activate .venv and install the package with: pip install -e '.[dev]'")
